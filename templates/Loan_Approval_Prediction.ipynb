# %%
# Loan Approval Prediction based on Machine Learning Approach

# %% [markdown]
# ### Library Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Using Pandas Loading a Dataset

# %%
df=pd.read_csv(r"D:\Internships\Pantech\projects\Loan approval Prediction\loan with gui\loan with gui\train_loanPrediction.csv")

# %%
df.head(50)
# Out:
#      Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0   LP001002    Male      No         0.0      Graduate            No
# 1   LP001003    Male     Yes         1.0      Graduate            No
# 2   LP001005    Male     Yes         0.0      Graduate           Yes
# 3   LP001006    Male     Yes         0.0  Not Graduate            No
# 4   LP001008    Male      No         0.0      Graduate            No
# 5   LP001011    Male     Yes         2.0      Graduate           Yes
# 6   LP001013    Male     Yes         0.0  Not Graduate            No
# 7   LP001014    Male     Yes         3.0      Graduate            No
# 8   LP001018    Male     Yes         2.0      Graduate            No
# 9   LP001020    Male     Yes         1.0      Graduate            No
# 10  LP001024    Male     Yes         2.0      Graduate            No
# 11  LP001027    Male     Yes         2.0      Graduate           NaN
# 12  LP001028    Male     Yes         2.0      Graduate            No
# 13  LP001029    Male      No         0.0      Graduate            No
# 14  LP001030    Male     Yes         2.0      Graduate            No
# 15  LP001032    Male      No         0.0      Graduate            No
# 16  LP001034    Male      No         1.0  Not Graduate            No
# 17  LP001036  Female      No         0.0      Graduate            No
# 18  LP001038    Male     Yes         0.0  Not Graduate            No
# 19  LP001041    Male     Yes         0.0      Graduate           NaN
# 20  LP001043    Male     Yes         0.0  Not Graduate            No
# 21  LP001046    Male     Yes         1.0      Graduate            No
# 22  LP001047    Male     Yes         0.0  Not Graduate            No
# 23  LP001050     NaN     Yes         2.0  Not Graduate            No
# 24  LP001052    Male     Yes         1.0      Graduate           NaN
# 25  LP001066    Male     Yes         0.0      Graduate           Yes
# 26  LP001068    Male     Yes         0.0      Graduate            No
# 27  LP001073    Male     Yes         2.0  Not Graduate            No
# 28  LP001086    Male      No         0.0  Not Graduate            No
# 29  LP001087  Female      No         2.0      Graduate           NaN
# 30  LP001091    Male     Yes         1.0      Graduate           NaN
# 31  LP001095    Male      No         0.0      Graduate            No
# 32  LP001097    Male      No         1.0      Graduate           Yes
# 33  LP001098    Male     Yes         0.0      Graduate            No
# 34  LP001100    Male      No         3.0      Graduate            No
# 35  LP001106    Male     Yes         0.0      Graduate            No
# 36  LP001109    Male     Yes         0.0      Graduate            No
# 37  LP001112  Female     Yes         0.0      Graduate            No
# 38  LP001114    Male      No         0.0      Graduate            No
# 39  LP001116    Male      No         0.0  Not Graduate            No
# 40  LP001119    Male      No         0.0      Graduate            No
# 41  LP001120    Male      No         0.0      Graduate            No
# 42  LP001123    Male     Yes         0.0      Graduate            No
# 43  LP001131    Male     Yes         0.0      Graduate            No
# 44  LP001136    Male     Yes         0.0  Not Graduate           Yes
# 45  LP001137  Female      No         0.0      Graduate            No
# 46  LP001138    Male     Yes         1.0      Graduate            No
# 47  LP001144    Male     Yes         0.0      Graduate            No
# 48  LP001146  Female     Yes         0.0      Graduate            No
# 49  LP001151  Female      No         0.0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
# 5              5417             4196.0       267.0             360.0
# 6              2333             1516.0        95.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 10             3200              700.0        70.0             360.0
# 11             2500             1840.0       109.0             360.0
# 12             3073             8106.0       200.0             360.0
# 13             1853             2840.0       114.0             360.0
# 14             1299             1086.0        17.0             120.0
# 15             4950                0.0       125.0             360.0
# 16             3596                0.0       100.0             240.0
# 17             3510                0.0        76.0             360.0
# 18             4887                0.0       133.0             360.0
# 19             2600             3500.0       115.0               NaN
# 20             7660                0.0       104.0             360.0
# 21             5955             5625.0       315.0             360.0
# 22             2600             1911.0       116.0             360.0
# 23             3365             1917.0       112.0             360.0
# 24             3717             2925.0       151.0             360.0
# 25             9560                0.0       191.0             360.0
# 26             2799             2253.0       122.0             360.0
# 27             4226             1040.0       110.0             360.0
# 28             1442                0.0        35.0             360.0
# 29             3750             2083.0       120.0             360.0
# 30             4166             3369.0       201.0             360.0
# 31             3167                0.0        74.0             360.0
# 32             4692                0.0       106.0             360.0
# 33             3500             1667.0       114.0             360.0
# 34            12500             3000.0       320.0             360.0
# 35             2275             2067.0         NaN             360.0
# 36             1828             1330.0       100.0               NaN
# 37             3667             1459.0       144.0             360.0
# 38             4166             7210.0       184.0             360.0
# 39             3748             1668.0       110.0             360.0
# 40             3600                0.0        80.0             360.0
# 41             1800             1213.0        47.0             360.0
# 42             2400                0.0        75.0             360.0
# 43             3941             2336.0       134.0             360.0
# 44             4695                0.0        96.0               NaN
# 45             3410                0.0        88.0               NaN
# 46             5649                0.0        44.0             360.0
# 47             5821                0.0       144.0             360.0
# 48             2645             3440.0       120.0             360.0
# 49             4000             2275.0       144.0             360.0
#
#     Credit_History Property_Area Loan_Status  TotalIncome  TotalIncome_log
# 0              1.0         Urban           Y       5849.0         8.674026
# 1              1.0         Rural           N       6091.0         8.714568
# 2              1.0         Urban           Y       3000.0         8.006368
# 3              1.0         Urban           Y       4941.0         8.505323
# 4              1.0         Urban           Y       6000.0         8.699515
# 5              1.0         Urban           Y       9613.0         9.170872
# 6              1.0         Urban           Y       3849.0         8.255569
# 7              0.0     Semiurban           N       5540.0         8.619750
# 8              1.0         Urban           Y       5532.0         8.618305
# 9              1.0     Semiurban           N      23809.0        10.077819
# 10             1.0         Urban           Y       3900.0         8.268732
# 11             1.0         Urban           Y       4340.0         8.375630
# 12             1.0         Urban           Y      11179.0         9.321792
# 13             1.0         Rural           N       4693.0         8.453827
# 14             1.0         Urban           Y       2385.0         7.776954
# 15             1.0         Urban           Y       4950.0         8.507143
# 16             NaN         Urban           Y       3596.0         8.187577
# 17             0.0         Urban           N       3510.0         8.163371
# 18             1.0         Rural           N       4887.0         8.494334
# 19             1.0         Urban           Y       6100.0         8.716044
# 20             0.0         Urban           N       7660.0         8.943767
# 21             1.0         Urban           Y      11580.0         9.357035
# 22             0.0     Semiurban           N       4511.0         8.414274
# 23             0.0         Rural           N       5282.0         8.572060
# 24             NaN     Semiurban           N       6642.0         8.801168
# 25             1.0     Semiurban           Y       9560.0         9.165343
# 26             1.0     Semiurban           Y       5052.0         8.527539
# 27             1.0         Urban           Y       5266.0         8.569026
# 28             1.0         Urban           N       1442.0         7.273786
# 29             1.0     Semiurban           Y       5833.0         8.671287
# 30             NaN         Urban           N       7535.0         8.927314
# 31             1.0         Urban           N       3167.0         8.060540
# 32             1.0         Rural           N       4692.0         8.453614
# 33             1.0     Semiurban           Y       5167.0         8.550048
# 34             1.0         Rural           N      15500.0         9.648595
# 35             1.0         Urban           Y       4342.0         8.376090
# 36             0.0         Urban           N       3158.0         8.057694
# 37             1.0     Semiurban           Y       5126.0         8.542081
# 38             1.0         Urban           Y      11376.0         9.339261
# 39             1.0     Semiurban           Y       5416.0         8.597113
# 40             1.0         Urban           N       3600.0         8.188689
# 41             1.0         Urban           Y       3013.0         8.010692
# 42             NaN         Urban           Y       2400.0         7.783224
# 43             1.0     Semiurban           Y       6277.0         8.744647
# 44             1.0         Urban           Y       4695.0         8.454253
# 45             1.0         Urban           Y       3410.0         8.134468
# 46             1.0         Urban           Y       5649.0         8.639234
# 47             1.0         Urban           Y       5821.0         8.669227
# 48             0.0         Urban           N       6085.0         8.713582
# 49             1.0     Semiurban           Y       6275.0         8.744329

# %% [markdown]
# ### Pre Processing

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1480, 13)

# %%
df.describe()
# Out:
#         Dependents  ApplicantIncome  CoapplicantIncome   LoanAmount  \
# count  1443.000000      1480.000000        1480.000000  1430.000000
# mean      0.786556      5420.054054        1668.158622   148.002797
# std       1.013863      6127.461081        3111.846669    86.080796
# min       0.000000       150.000000           0.000000     9.000000
# 25%       0.000000      2873.000000           0.000000   100.000000
# 50%       0.000000      3750.000000        1287.000000   128.000000
# 75%       2.000000      5818.000000        2306.000000   166.750000
# max       3.000000     81000.000000       41667.000000   700.000000
#
#        Loan_Amount_Term  Credit_History
# count       1456.000000     1354.000000
# mean         341.587912        0.842688
# std           66.759293        0.364229
# min           12.000000        0.000000
# 25%          360.000000        1.000000
# 50%          360.000000        1.000000
# 75%          360.000000        1.000000
# max          480.000000        1.000000

# %%
df.isnull().sum()
# Out:
# Loan_ID                0
# Gender                35
# Married                5
# Dependents            37
# Education              0
# Self_Employed         72
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            50
# Loan_Amount_Term      24
# Credit_History       126
# Property_Area          0
# Loan_Status            0
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
val=df1.index

# %%
df1['ApplicantIncome'].hist(bins=10)
plt.title("Application Income")
plt.xlabel('Amount')
plt.ylabel('No.of App')
# Out:
# Text(0, 0.5, 'No.of App')

# %%
df['CoapplicantIncome'].hist(bins=10)
plt.title("CoApplication Income")
plt.xlabel('Amount')
plt.ylabel('No.of CoApp')
# Out:
# Text(0, 0.5, 'No.of CoApp')

# %%
df['LoanAmount'].hist(bins=10) 
plt.title("Loan Amount")
plt.xlabel('Amount')
plt.ylabel('No.of CoApp')
# Out:
# Text(0, 0.5, 'No.of CoApp')

# %%
#combining the above 2 plots in a stacked chart
stack_chart = pd.crosstab(df['Credit_History'], df['Loan_Status'])
stack_chart.plot(kind='bar', stacked=True, color=['green','red'], grid=False)
stack_chart = pd.crosstab(df['Gender'], df['Loan_Status'])
stack_chart.plot(kind='bar', stacked=True, color=['green','red'], grid=False)
# Out:
# <Axes: xlabel='Gender'>

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df['TotalIncome_log'] = np.log(df['TotalIncome'])
df['LoanAmount'].hist(bins=10) 
plt.xlabel('Amount')
# Out:
# Text(0.5, 0, 'Amount')

# %%
df2=df1.drop(["Loan_ID"],axis=1)

# %% [markdown]
# ### LabelEncoder

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

# %%
df2['LGender'] = le.fit_transform(df2['Gender'].values.reshape(-1,1).ravel())
df2.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
# 5   Male     Yes         2.0      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status  LGender
# 1         Rural           N        1
# 2         Urban           Y        1
# 3         Urban           Y        1
# 4         Urban           Y        1
# 5         Urban           Y        1

# %%
df2['LMarried']=le.fit_transform(df2['Married'].values.reshape(-1,1).ravel())
df2.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
# 5   Male     Yes         2.0      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status  LGender  LMarried
# 1         Rural           N        1         1
# 2         Urban           Y        1         1
# 3         Urban           Y        1         1
# 4         Urban           Y        1         0
# 5         Urban           Y        1         1

# %%
df2['LSelf_Employed']=le.fit_transform(df2["Self_Employed"].values.reshape(-1,1).ravel())

# %%
df2['LLoan_Status']=le.fit_transform(df2["Loan_Status"].values.reshape(-1,1).ravel())

# %%
df2['LEducation']=le.fit_transform(df2["Education"].values.reshape(-1,1).ravel())

# %%
df2['LProperty_Area']=le.fit_transform(df2["Property_Area"].values.reshape(-1,1).ravel())
df2.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
# 5   Male     Yes         2.0      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status  LGender  LMarried  LSelf_Employed  LLoan_Status  \
# 1         Rural           N        1         1               0             0
# 2         Urban           Y        1         1               1             1
# 3         Urban           Y        1         1               0             1
# 4         Urban           Y        1         0               0             1
# 5         Urban           Y        1         1               1             1
#
#    LEducation  LProperty_Area
# 1           0               0
# 2           0               2
# 3           1               2
# 4           0               2
# 5           0               2

# %%
df2=df2.drop(["Self_Employed"],axis=1)
df2=df2.drop(["Loan_Status"],axis=1)
df2=df2.drop(["Property_Area"],axis=1)
df2=df2.drop(["Married"],axis=1)
df2=df2.drop(["Gender"],axis=1)
df2=df2.drop(["Education"],axis=1)
df2.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1         1.0             4583             1508.0       128.0
# 2         0.0             3000                0.0        66.0
# 3         0.0             2583             2358.0       120.0
# 4         0.0             6000                0.0       141.0
# 5         2.0             5417             4196.0       267.0
#
#    Loan_Amount_Term  Credit_History  LGender  LMarried  LSelf_Employed  \
# 1             360.0             1.0        1         1               0
# 2             360.0             1.0        1         1               1
# 3             360.0             1.0        1         1               0
# 4             360.0             1.0        1         0               0
# 5             360.0             1.0        1         1               1
#
#    LLoan_Status  LEducation  LProperty_Area
# 1             0           0               0
# 2             1           0               2
# 3             1           1               2
# 4             1           0               2
# 5             1           0               2

# %% [markdown]
# ### Classification

# %%
x=df2.iloc[:,df2.columns !='LLoan_Status']
y=df2.iloc[:,df2.columns =='LLoan_Status']

# %%
x.head()
# Out:
#    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 1         1.0             4583             1508.0       128.0
# 2         0.0             3000                0.0        66.0
# 3         0.0             2583             2358.0       120.0
# 4         0.0             6000                0.0       141.0
# 5         2.0             5417             4196.0       267.0
#
#    Loan_Amount_Term  Credit_History  LGender  LMarried  LSelf_Employed  \
# 1             360.0             1.0        1         1               0
# 2             360.0             1.0        1         1               1
# 3             360.0             1.0        1         1               0
# 4             360.0             1.0        1         0               0
# 5             360.0             1.0        1         1               1
#
#    LEducation  LProperty_Area
# 1           0               0
# 2           0               2
# 3           1               2
# 4           0               2
# 5           0               2

# %%
y.head()
# Out:
#    LLoan_Status
# 1             0
# 2             1
# 3             1
# 4             1
# 5             1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (928, 11)

# %%
x_train
# Out:
#       Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 968          0.0             2400             1863.0       104.0
# 496          0.0             2600             1700.0       107.0
# 967          0.0             3762             1666.0       135.0
# 527          1.0             5285             1430.0       161.0
# 340          3.0             2647             1587.0       173.0
# ...          ...              ...                ...         ...
# 1284         0.0             2500                0.0        67.0
# 625          2.0             3547                0.0        80.0
# 1334         2.0             5391                0.0       130.0
# 1058         0.0             3033             1459.0        95.0
# 521          0.0             2500                0.0        55.0
#
#       Loan_Amount_Term  Credit_History  LGender  LMarried  LSelf_Employed  \
# 968              360.0             0.0        0         0               0
# 496              360.0             1.0        1         1               0
# 967              360.0             1.0        0         0               0
# 527              360.0             0.0        1         1               0
# 340              360.0             1.0        1         1               0
# ...                ...             ...      ...       ...             ...
# 1284             360.0             1.0        0         0               0
# 625              360.0             0.0        1         0               0
# 1334             360.0             1.0        1         1               0
# 1058             360.0             1.0        1         1               0
# 521              360.0             1.0        1         0               0
#
#       LEducation  LProperty_Area
# 968            0               2
# 496            1               0
# 967            0               0
# 527            1               1
# 340            1               0
# ...          ...             ...
# 1284           0               2
# 625            0               0
# 1334           0               2
# 1058           0               2
# 521            0               1
#
# [928 rows x 11 columns]

# %%
y_train
# Out:
#       LLoan_Status
# 968              0
# 496              1
# 967              1
# 527              1
# 340              0
# ...            ...
# 1284             1
# 625              0
# 1334             1
# 1058             1
# 521              1
#
# [928 rows x 1 columns]

# %%
y_test.shape
# Out:
# (232, 1)

# %%
np1=df2.values

# %%
#plt.subplot(1,2,1)
sns.countplot(x="Gender", order=['Male','Female'], data=df, palette="Set1")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11612\4234423503.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Gender", order=['Male','Female'], data=df, palette="Set1")

# %%
#plt.subplot(1,2,1)
sns.countplot(x="Married", order=['Yes','No'], data=df, palette="Set1")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11612\2068639771.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Married", order=['Yes','No'], data=df, palette="Set1")

# %%
#plt.subplot(1,2,1)
sns.countplot(x="Property_Area", order=['Urban','Rural','Semiurban'], data=df, palette="Set1")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11612\94966207.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Property_Area", order=['Urban','Rural','Semiurban'], data=df, palette="Set1")

# %%
#plt.subplot(1,2,1)
sns.countplot(x="Education", order=['Graduate','Not Graduate'], data=df, palette="Set1")
plt.show()

# %% [markdown]
# # Training the Algorithams

# %% [markdown]
# #### 1.SVM-Support Vector Machine

# %%
from sklearn import svm
from sklearn import metrics

# %%
model1=svm.SVC()

# %%
model1.fit(x_train,y_train)
# Out:
# D:\Apps\anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
xpredict=model1.predict(x_test)

# %%
svm=metrics.accuracy_score(y_test,xpredict)
print(svm)
# Out:
# 0.646551724137931

# %%
svm=model1.score(x_test,y_test)
svm
# Out:
# 0.646551724137931

# %% [markdown]
# ### 2.LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model2=LogisticRegression()

# %%
model2.fit(x_train,y_train)
# Out:
# D:\Apps\anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\Apps\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
xpredict=model2.predict(x_test)

# %%
lr=metrics.accuracy_score(y_test,xpredict)
print(lr)
# Out:
# 0.8017241379310345

# %% [markdown]
# ### 3.Decision Tree algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model3=DecisionTreeClassifier()

# %%
model3.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
xpredict=model3.predict(x_test)

# %%
dt=metrics.accuracy_score(y_test,xpredict)
print(dt)
# Out:
# 0.9137931034482759

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model4=GaussianNB()

# %%
model4.fit(x_train,y_train)
# Out:
# D:\Apps\anaconda\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
xpredict=model4.predict(x_test)

# %%
nv=metrics.accuracy_score(y_test,xpredict)
print(dt)
# Out:
# 0.9137931034482759

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(x_train, y_train)

# Predict on the test set
y_pred = rf_model.predict(x_test)

# Evaluate performance
accuracy = metrics.accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")
# Out:
# D:\Apps\anaconda\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Model Accuracy: 0.9181

# %% [markdown]
#  # Graph_Comparision

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()

objects = ('Support Vector',' LogisticRegression','Decision Tree' , 'Naive Bayes', 'Random Forest')
y_pos = np.arange(len(objects))
performance = [svm,lr,dt,nv, accuracy]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Accuracy')
plt.title('Model Comparison')

plt.show()

# %%
import pickle
pickle.dump(rf_model, open('rf_model.pkl','wb'))
